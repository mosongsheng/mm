# %%
import mytools
import pandas as pd
from pyreadstat import pyreadstat
国家认同原始数据,mata=mytools.读取SPSS数据(R'identity.sav')
import matplotlib.pyplot as plt  
result = 国家认同原始数据['年级'].value_counts()
labels =result.index
sizes =result.values
plt.pie(sizes, labels=labels, autopct='%1.1f%%')  
  
# 显示图形  99
plt.show()

# %%
import matplotlib.pyplot as pit 
import pandas as pd
def plot_veriable_pie(data_tabie, veriable):
#准备绘图数据
 data = data_table[variable].value_counts()
#创建饼图
fig1, ax1= plt.subplots()
ax1.pie(data, labels = data.index, autopct='%1.1f%%')
pit. axis('equal') # Equal aspect ratio ensures that pie is drawn as a circle.
plt.title('Pie Chart of' + variable)
plt.show
import mytools
di2.meta = mytools.读取SPSS数据(R'identity.sav'
plot_variable_pie(df2,“年级”)
dt2r年级1.value_countsO
# Out:
#   Cell In[8], line 9
#     pit. axis('equal) # Equal aspect ratio ensures that pie is drawn as a circle.
#                                                                                  ^
# SyntaxError: EOL while scanning string literal

# %%
import matplotlib.pyplot as plt  
import pandas as pd  
import mytools  
  
def plot_variable_pie(data_table, variable):  
    # 准备绘图数据  
    data = data_table[variable].value_counts()  
    # 创建饼图  
    fig1, ax1 = plt.subplots()  
    ax1.pie(data, labels = data.index, autopct='%1.1f%%')  
    plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.  
    plt.title("Pie Chart of " + variable)  
    plt.show()  
  
df2,meta = mytools.读取SPSS数据(R'identity.sav')  # 使用正确的文件路径和正确的函数名  
plot_variable_pie(df2, "年级")
