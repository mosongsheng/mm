# %%
import pandas as pd
from pyreadstat import pyreadstat
import mytools  
import matplotlib.pyplot as plt 
df1 = pd.read_csv(R'类别变量练习数据 (1).csv',encoding='GBK')

# %%
tau_y=mytools.goodmanKruska_tau_y(df1,'父亲职业重新编码','母亲职业重新编码')
tau_y
# Out:
# 0.23054798667877666

# %%
mytools.相关系数强弱判断(tau_y)
# Out:
# '弱相关'

# %%
mytools.制作交叉表(df1,'父亲职业重新编码','母亲职业重新编码')
# Out:
# 母亲职业重新编码  上市民企公司        个体      事业单位       公务员   国企      家庭主妇    无        民企  \
# 父亲职业重新编码
# 个体           0.0  0.571429  0.000000  0.000000  0.0  0.272727  0.0  0.142857
# 事业单位         0.0  0.000000  0.222222  0.000000  0.0  0.000000  0.0  0.000000
# 公务员          0.0  0.142857  0.666667  0.714286  0.5  0.000000  0.0  0.571429
# 国企           0.0  0.142857  0.000000  0.000000  0.5  0.090909  1.0  0.142857
# 家庭主妇         0.0  0.000000  0.000000  0.000000  0.0  0.181818  0.0  0.000000
# 家庭父亲         0.0  0.000000  0.000000  0.071429  0.0  0.000000  0.0  0.000000
# 民企           1.0  0.142857  0.111111  0.214286  0.0  0.454545  0.0  0.142857
#
# 母亲职业重新编码       All
# 父亲职业重新编码
# 个体        0.153846
# 事业单位      0.038462
# 公务员       0.423077
# 国企        0.096154
# 家庭主妇      0.038462
# 家庭父亲      0.019231
# 民企        0.230769

# %%
import matplotlib.pyplot as plt  
result = df1['父亲职业重新编码'].value_counts()
labels =result.index
sizes =result.values
plt.pie(sizes, labels=labels, autopct='%1.1f%%')  
  
# 显示图形  
plt.show()

# %%
import matplotlib.pyplot as plt  
result = df1['母亲职业重新编码'].value_counts()
labels =result.index
sizes =result.values
plt.pie(sizes, labels=labels, autopct='%1.1f%%')  
  
# 显示图形  
plt.show()
