# %%
import mytools
import pandas as pd
from pyreadstat import pyreadstat
国家认同原始数据,mata=mytools.读取SPSS数据(R'identity.sav')

# %%
import matplotlib.pyplot as plt  
result = 国家认同原始数据['政治面貌'].value_counts()
labels =result.index
sizes =result.values
plt.pie(sizes, labels=labels, autopct='%1.1f%%')  
  
# 显示图形  99
plt.show()

# %%
result=df2['年级'].value_counts()

# %%
import pandas as pd
import matplotlib.pyplot as plt

def plot_variable_pie(data_table, variable):
#准备绘图数据
   data = data_table[variable].value_counts()

#创建饼图
   figl, ax1 =plt.subplots()
   ax1.pie(data, labels = data.index, autopcf="%1.1f%8")
   ax1.axis('equal') # Equal aspect ratio ensures that pie is drawn as acircle.
   plt.show()

# %%
df2['年级'].value_counts()
# Out:
# 年级
# 大一    307
# 大二    278
# 大三    172
# 大四     94
# 预科     14
# Name: count, dtype: int64

# %%
import mytools
df2,meta=mata=mytools.读取SPSS数据(R'identity.sav')
result = 国家认同原始数据['年级'].value_counts()
labels =result.index
sizes =result.values
plt.pie(sizes, labels=labels, autopct='%1.1f%%')  
  
# 显示图形  99
plt.show()
